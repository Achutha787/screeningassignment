# %%
##Example code of abstract class

from abc import ABC,abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
    @abstractmethod
    def perimeter(self):
        pass
class Square(Shape):
    def __init__(self,side):
        self.__side=side
    def area(self):
        return self.__side * self.__side
    def perimeter(self):
        return 4* self.__side
square= Square(5)
print(square.area())
print(square.perimeter())
# Out:
# 25
# 20

# %%
##Example of multiple Inheritance
class A:
    def method1(self):
        print("A class method is called")
class B(A):
    def method2(self):
        print("B class method is called")
    def method6(self):
        print("E class method is called")
class C(A):
    def method3(self):
        print("C class method is called")
class D(B,C):
    def method4(self):
        print("D class method is called")
d=D()
d.method3()
d.method6()
d.method4()
d.method3()
d.method1()
d.method2()
# Out:
# C class method is called
# E class method is called
# D class method is called
# C class method is called
# A class method is called
# B class method is called

# %%
##Example of decorators
def div_decorator(func):
    def inner(x,y):
        if y==0:
            return "give proper input"
        return func(x,y)
    return inner
@div_decorator
def div(a,b):
    return a/b
print(div(4,0))
##Decorator is a callable function object which will take a function and modify it and it will 
#return the function.Decorator needs to take a function as a parameter and adds functionality to
##the function and the function needs to return another function
# Out:
# give proper input

# %%
##Creating a file and replacing its file content
f=open("example.txt",'w+')
f.write("This is a placement assignment")
print("original file")
f.close()
f=open("example.txt",'w+')
f.write("this is a screening assignment")
print("replaced file")
f= open("example.txt",'r')
print(f.read())
# Out:
# original file
# replaced file
# this is a screening assignment
